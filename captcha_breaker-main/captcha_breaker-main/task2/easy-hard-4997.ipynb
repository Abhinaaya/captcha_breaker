# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset, random_split
from PIL import Image
import os
import random
import csv

class dataset(Dataset):
    def __init__(self, data_dir, transform):
        self.data_dir = data_dir
        self.image_files = [file for file in os.listdir(self.data_dir) if file.endswith('.png')]
        self.transform = transform
        self.char_to_index = {char : (i+1) for i, char in enumerate("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ")}
        self.index_to_char = {self.char_to_index[char]:char for char in self.char_to_index}
        self.index_to_char[0] = '<blank>'
    
    def __len__(self):
        return len(self.image_files)
    
    def __getitem__(self, idx):
        img_name = self.image_files[idx]
        image_path = os.path.join(self.data_dir, img_name)
        image = Image.open(image_path).convert('L')
        image =self.transform(image)
        label = img_name[:-4]
        label_indices = [self.char_to_index[i] for i in label]
        return image, torch.tensor(label_indices)

transform = transforms.Compose([
    transforms.Resize((32,128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

class CRNN(nn.Module):
    def __init__(self, num_chars):
        super().__init__()
        
        self.cnn = nn.Sequential(
            nn.Conv2d(1,64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),  # 64 --> 32
            nn.Dropout(0.1),
            
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d((2, 1)),  # 32 --> 16 only height
            nn.Dropout(0.1),
                
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d((2, 1)),  # 16 --> 8 only height
            nn.Dropout(0.1),   
        )
        
        self.lstm1 = nn.LSTM(512 * 2, 256, bidirectional=True, batch_first=True)
        self.linear1 = nn.Linear(512, 256)
        self.lstm2 = nn.LSTM(256, 256, bidirectional=True, batch_first=True)
        self.linear2 = nn.Linear(512, num_chars + 1)
        
    def forward(self,x):
        conv = self.cnn(x)  # [batch, 512, 2, 32]
        batch, channel, height, width = conv.size()
        conv = conv.permute(0, 3, 1, 2)  # [batch, width, channel, height]
        conv = conv.reshape(batch, width, channel * height)  # [batch, width, feature]
        
        lstm_out, _ = self.lstm1(conv)  # [batch, width, 512]
        lstm_out = self.linear1(lstm_out)  # [batch, width, 256]
        lstm_out, _ = self.lstm2(lstm_out)  # [batch, width, 512]
        output = self.linear2(lstm_out)  # [batch, width, num_chars + 1]
        return output

def decode_predictions(output, index_to_char):
    if len(output.shape) == 2:
        output = output.unsqueeze(0)
    
    output = nn.functional.log_softmax(output, dim=-1)
    predictions = torch.argmax(output, dim=-1) 
    
    batch_results = []
    for batch_pred in predictions:
        chars = []
        prev_char = None
        
        for p in batch_pred:
            char_idx = p.item()
            if char_idx != 0 and char_idx != prev_char:  
                if char_idx in index_to_char:
                    chars.append(index_to_char[char_idx])
            prev_char = char_idx
        
        batch_results.append(''.join(chars))
    
    return batch_results[0] if len(batch_results) == 1 else batch_results

def predict_captcha(model, image_path, transform, device, index_to_char):
    image = Image.open(image_path).convert('L')
    image = transform(image)
    image = image.unsqueeze(0)
    
    model.eval()
    image = image.to(device)
    
    with torch.no_grad():
        output = model(image)
        predicted_text = decode_predictions(output, index_to_char)
    
    model.train()
    return predicted_text


def train_model(model, train_data, test_data, optimizer, loss_func, device, index_to_char, num_epochs=100):
    model.train()
    best_accuracy = 0
    
    for epoch in range(num_epochs):
        total_loss = 0
        for batch_idx, (images, labels) in enumerate(train_data):
            images = images.to(device)
            labels = labels.to(device)
            
            batch_size = images.size(0)
            outputs = model(images)  # [batch, width, num_chars + 1]
            
            input_lengths = torch.full(size=(batch_size,), fill_value=outputs.size(1), dtype=torch.long)
            target_lengths = torch.sum(labels != 0, dim=1)
            
            outputs = outputs.log_softmax(2) 
            outputs = outputs.permute(1, 0, 2)
            
            optimizer.zero_grad()
            loss = loss_func(outputs, labels, input_lengths, target_lengths)
            loss.backward()
            
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5)
            optimizer.step()
            
            total_loss += loss.item()
            
        model.eval()
        correct = 0
        total_samples = len(test_data.dataset)
        random_index = random.randint(0,total_samples)
        
        all_results = []
        
        with torch.no_grad():
            for i, (test_img, test_label) in enumerate(test_data):
                test_img = test_img.to(device)
                predicted_text = decode_predictions(model(test_img), index_to_char)
                true_text = ''.join([index_to_char[idx.item()] for idx in test_label[0] if idx.item() != 0])
                
                all_results.append({
                    'original': true_text,
                    'predicted': predicted_text,
                    'correct': predicted_text == true_text
                })
                
                if predicted_text == true_text:
                    correct += 1
                
                if i == random_index:
                    print(f'Sample {i+1}')
                    print(f'Original text: {true_text}')
                    print(f'Predicted: {predicted_text}\n')
        
        accuracy = correct / total_samples
        
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': accuracy,
            }, 'best_model.pth')
            
            with open('easy_hard_4997.csv', 'w', newline='') as f:
                writer = csv.DictWriter(f, fieldnames=['original', 'predicted', 'correct'])
                writer.writeheader()
                writer.writerows(all_results)
            
            print(f'New best model saved with accuracy: {accuracy:.4f}')
        
        model.train()
        print(f'Epoch {epoch+1} complete, Average Loss: {total_loss/len(train_data):.4f}')
        print(f'Accuracy: {accuracy:.4f}')


def collate_fn(batch):
    batch.sort(key=lambda x: len(x[1]), reverse=True)
    images, labels = zip(*batch)
    images = torch.stack(images, 0)
    lengths = [len(label) for label in labels]
    max_length = max(lengths)
    padded_labels = torch.zeros(len(labels), max_length).long()
    for i, label in enumerate(labels):
        padded_labels[i, :len(label)] = label
        
    return images, padded_labels

data = dataset('/kaggle/input/easy-hard-5000/easy_hard_5000', transform)
num_chars = len(data.index_to_char) 
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = CRNN(num_chars).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.003)

train_size = int(0.8 * len(data))
test_size = len(data) - train_size
train_dataset, test_dataset = random_split(data, [train_size, test_size])
train_data = DataLoader(train_dataset, batch_size=16, shuffle=True, collate_fn=collate_fn)
test_data = DataLoader(test_dataset, shuffle=True, collate_fn=collate_fn)
loss_func = nn.CTCLoss(blank=0, zero_infinity=True, reduction='mean')

train_model(model, train_data, test_data, optimizer, loss_func, device, data.index_to_char, num_epochs=100)
# Out:
# Sample 291
# Original text: fNseyZ
# Predicted:
#
# Epoch 1 complete, Average Loss: 4.3829
# Accuracy: 0.0000
# Sample 991
# Original text: Pmqdzuh
# Predicted:
#
# Epoch 2 complete, Average Loss: 4.0416
# Accuracy: 0.0000
# Sample 18
# Original text: Phgqj
# Predicted: I
#
# Epoch 3 complete, Average Loss: 3.9557
# Accuracy: 0.0000
# Sample 510
# Original text: cWzcT
# Predicted: Ns
#
# Epoch 4 complete, Average Loss: 3.8666
# Accuracy: 0.0000
# Sample 912
# Original text: mqur
# Predicted: FCaX
#
# Epoch 5 complete, Average Loss: 3.5833
# Accuracy: 0.0000
# Sample 421
# Original text: ItmU
# Predicted: Bph
#
# Epoch 6 complete, Average Loss: 3.1823
# Accuracy: 0.0000
# Sample 386
# Original text: Xjndpv
# Predicted: Zlndpm
#
# New best model saved with accuracy: 0.0040
# Epoch 7 complete, Average Loss: 2.7837
# Accuracy: 0.0040
# Sample 104
# Original text: Tmxbh
# Predicted: Kmxbh
#
# Epoch 8 complete, Average Loss: 2.5528
# Accuracy: 0.0030
# Sample 829
# Original text: jiFDeFJ
# Predicted: XNoty
#
# Epoch 9 complete, Average Loss: 2.4138
# Accuracy: 0.0010
# Sample 425
# Original text: bAbd
# Predicted: uLd
#
# New best model saved with accuracy: 0.0070
# Epoch 10 complete, Average Loss: 2.2739
# Accuracy: 0.0070
# Sample 663
# Original text: Pyhkzw
# Predicted: Zyhkz
#
# New best model saved with accuracy: 0.0210
# Epoch 11 complete, Average Loss: 2.1168
# Accuracy: 0.0210
# Sample 365
# Original text: hLuIJA
# Predicted: wbxjdA
#
# New best model saved with accuracy: 0.0280
# Epoch 12 complete, Average Loss: 1.9862
# Accuracy: 0.0280
# Sample 510
# Original text: Zmhqdn
# Predicted: Smhqdn
#
# Epoch 13 complete, Average Loss: 1.8356
# Accuracy: 0.0280
# Sample 346
# Original text: Tdcitn
# Predicted: Adctn
#
# New best model saved with accuracy: 0.0410
# Epoch 14 complete, Average Loss: 1.7336
# Accuracy: 0.0410
# Sample 682
# Original text: Mrktx
# Predicted: Yrtktx
#
# Epoch 15 complete, Average Loss: 1.6326
# Accuracy: 0.0340
# Sample 885
# Original text: Wpenbem
# Predicted: Apenbem
#
# New best model saved with accuracy: 0.0800
# Epoch 16 complete, Average Loss: 1.5091
# Accuracy: 0.0800
# Sample 664
# Original text: QwlKA
# Predicted: awiIX
#
# Epoch 17 complete, Average Loss: 1.4307
# Accuracy: 0.0410
# Sample 84
# Original text: Guyee
# Predicted: Soyee
#
# Epoch 18 complete, Average Loss: 1.3129
# Accuracy: 0.0750
# Sample 62
# Original text: Yqzujea
# Predicted: Yqzujea
#
# New best model saved with accuracy: 0.1500
# Epoch 19 complete, Average Loss: 1.2602
# Accuracy: 0.1500
# Sample 148
# Original text: Ebiohca
# Predicted: Sbiohca
#
# New best model saved with accuracy: 0.1750
# Epoch 20 complete, Average Loss: 1.1648
# Accuracy: 0.1750
# Sample 822
# Original text: bRSp
# Predicted: tPSP
#
# New best model saved with accuracy: 0.1930
# Epoch 21 complete, Average Loss: 1.0971
# Accuracy: 0.1930
# Sample 524
# Original text: bYPP
# Predicted: aYpp
#
# New best model saved with accuracy: 0.2280
# Epoch 22 complete, Average Loss: 1.0322
# Accuracy: 0.2280
# Sample 756
# Original text: Bovdrw
# Predicted: Bovdrw
#
# Epoch 23 complete, Average Loss: 0.9944
# Accuracy: 0.2100
# Sample 594
# Original text: Kbvjwx
# Predicted: Kbvjwx
#
# Epoch 24 complete, Average Loss: 0.9803
# Accuracy: 0.1750
# Sample 746
# Original text: fsZiwm
# Predicted: RsZiwm
#
# New best model saved with accuracy: 0.2450
# Epoch 25 complete, Average Loss: 0.9077
# Accuracy: 0.2450
# Sample 86
# Original text: Bvdwo
# Predicted: Bvdwo
#
# New best model saved with accuracy: 0.2670
# Epoch 26 complete, Average Loss: 0.8283
# Accuracy: 0.2670
# Sample 975
# Original text: Ufrf
# Predicted: Ufrf
#
# New best model saved with accuracy: 0.2840
# Epoch 27 complete, Average Loss: 0.8073
# Accuracy: 0.2840
# Sample 177
# Original text: Mqtcly
# Predicted: Wqtcly
#
# Epoch 28 complete, Average Loss: 0.7884
# Accuracy: 0.2660
# Sample 789
# Original text: Xavszi
# Predicted: Xavszi
#
# New best model saved with accuracy: 0.3530
# Epoch 29 complete, Average Loss: 0.7698
# Accuracy: 0.3530
# Sample 482
# Original text: Bzygxpj
# Predicted: Szyexbj
#
# Epoch 30 complete, Average Loss: 0.7308
# Accuracy: 0.0900
# Sample 507
# Original text: Yqqh
# Predicted: Yqqh
#
# Epoch 31 complete, Average Loss: 0.6709
# Accuracy: 0.3530
# Sample 733
# Original text: RJVsIir
# Predicted: PjVzlr
#
# New best model saved with accuracy: 0.4200
# Epoch 32 complete, Average Loss: 0.6508
# Accuracy: 0.4200
# Sample 982
# Original text: Rxiabiz
# Predicted: Rxiabiz
#
# Epoch 33 complete, Average Loss: 0.6474
# Accuracy: 0.3740
# Sample 165
# Original text: crABQh
# Predicted: crKEQh
#
# Epoch 34 complete, Average Loss: 0.6201
# Accuracy: 0.4180
# Sample 933
# Original text: XqEwfkI
# Predicted: XqEwfki
#
# Epoch 35 complete, Average Loss: 0.5856
# Accuracy: 0.3590
# Sample 721
# Original text: Xdewq
# Predicted: Xdewq
#
# Epoch 36 complete, Average Loss: 0.5941
# Accuracy: 0.4080
# Sample 97
# Original text: thFcqlh
# Predicted: IhFcqlh
#
# Epoch 37 complete, Average Loss: 0.5727
# Accuracy: 0.4110
# Sample 762
# Original text: QdtgNj
# Predicted: OdkgNj
#
# New best model saved with accuracy: 0.4830
# Epoch 38 complete, Average Loss: 0.5583
# Accuracy: 0.4830
# Sample 514
# Original text: Zaimvmj
# Predicted: EaLmvmj
#
# Epoch 39 complete, Average Loss: 0.5675
# Accuracy: 0.3890
# Sample 124
# Original text: tLVOv
# Predicted: lLVQv
#
# New best model saved with accuracy: 0.4970
# Epoch 40 complete, Average Loss: 0.5656
# Accuracy: 0.4970
# Sample 958
# Original text: Ofnref
# Predicted: Ofnref
#
# Epoch 41 complete, Average Loss: 0.5319
# Accuracy: 0.2990
# Sample 74
# Original text: LcVL
# Predicted: icVi
#
# New best model saved with accuracy: 0.5180
# Epoch 42 complete, Average Loss: 0.5311
# Accuracy: 0.5180
# Sample 227
# Original text: rnobFD
# Predicted: TnobFD
#
# Epoch 43 complete, Average Loss: 0.5156
# Accuracy: 0.4840
# Sample 152
# Original text: Ycvzpuj
# Predicted: Ycvzpuj
#
# Epoch 44 complete, Average Loss: 0.4933
# Accuracy: 0.5060
# Sample 636
# Original text: XIqdn
# Predicted: xuUn
#
# Epoch 45 complete, Average Loss: 0.5043
# Accuracy: 0.4440
# Sample 234
# Original text: mczOdI
# Predicted: YgzQqi
#
# Epoch 46 complete, Average Loss: 0.4975
# Accuracy: 0.4810
# Sample 531
# Original text: KNnYW
# Predicted: KNnYW
#
# New best model saved with accuracy: 0.5210
# Epoch 47 complete, Average Loss: 0.4801
# Accuracy: 0.5210
# Sample 259
# Original text: Otoa
# Predicted: Otoa
#
# Epoch 48 complete, Average Loss: 0.5293
# Accuracy: 0.4280
# Sample 628
# Original text: Elnmuic
# Predicted: Elnmuic
#
# Epoch 49 complete, Average Loss: 0.5218
# Accuracy: 0.5000
# Sample 498
# Original text: Aubumw
# Predicted: Aubumw
#
# Epoch 50 complete, Average Loss: 0.4871
# Accuracy: 0.4980
# Sample 306
# Original text: TezS
# Predicted: TezS
#
# New best model saved with accuracy: 0.5360
# Epoch 51 complete, Average Loss: 0.4667
# Accuracy: 0.5360
# Sample 615
# Original text: TezS
# Predicted: TszS
#
# Epoch 52 complete, Average Loss: 0.4563
# Accuracy: 0.5210
# Sample 549
# Original text: Jogpic
# Predicted: Jogpic
#
# Epoch 53 complete, Average Loss: 0.4378
# Accuracy: 0.5260
# Sample 683
# Original text: Opdncoq
# Predicted: Opdncoq
#
# New best model saved with accuracy: 0.5640
# Epoch 54 complete, Average Loss: 0.4140
# Accuracy: 0.5640
# Sample 632
# Original text: Rmjxgyl
# Predicted: Rmixgyl
#
# Epoch 55 complete, Average Loss: 0.4404
# Accuracy: 0.5110
# Sample 724
# Original text: oRJL
# Predicted: oRJL
#
# Epoch 56 complete, Average Loss: 0.4351
# Accuracy: 0.5010
# Sample 432
# Original text: Yxvqq
# Predicted: Yxvqq
#
# Epoch 57 complete, Average Loss: 0.4354
# Accuracy: 0.5530
# Sample 809
# Original text: Hvsimhn
# Predicted: Hvsimhn
#
# Epoch 58 complete, Average Loss: 0.4054
# Accuracy: 0.5430
# Sample 438
# Original text: Vpoh
# Predicted: Vpoh
#
# New best model saved with accuracy: 0.5710
# Epoch 59 complete, Average Loss: 0.4151
# Accuracy: 0.5710
# Sample 579
# Original text: XulexRa
# Predicted: xXulcjRL
#
# New best model saved with accuracy: 0.5740
# Epoch 60 complete, Average Loss: 0.4125
# Accuracy: 0.5740
# Sample 452
# Original text: bqPYh
# Predicted: LqPYh
#
# Epoch 61 complete, Average Loss: 0.3795
# Accuracy: 0.5380
# Sample 661
# Original text: gAjpgyy
# Predicted: SAjpeyy
#
# Epoch 62 complete, Average Loss: 0.4234
# Accuracy: 0.5460
# Sample 55
# Original text: Cuxmzt
# Predicted: Cuxmzt
#
# Epoch 63 complete, Average Loss: 0.4568
# Accuracy: 0.5380
# Sample 712
# Original text: RUxg
# Predicted: RUyg
#
# Epoch 64 complete, Average Loss: 0.3850
# Accuracy: 0.5610
# Sample 586
# Original text: Tgogws
# Predicted: Tgogws
#
# New best model saved with accuracy: 0.5840
# Epoch 65 complete, Average Loss: 0.3732
# Accuracy: 0.5840
# Sample 540
# Original text: Uinfxl
# Predicted: Uinfxl
#
# Epoch 66 complete, Average Loss: 0.3984
# Accuracy: 0.5820
# Sample 393
# Original text: Kzemgbn
# Predicted: Kzemgbn
#
# New best model saved with accuracy: 0.6000
# Epoch 67 complete, Average Loss: 0.3883
# Accuracy: 0.6000
# Sample 213
# Original text: MggZput
# Predicted: NgSZPuf
#
# Epoch 68 complete, Average Loss: 0.3949
# Accuracy: 0.5940
# Sample 591
# Original text: Dypkvg
# Predicted: Dypkvg
#
# Epoch 69 complete, Average Loss: 0.4139
# Accuracy: 0.5370
# Sample 540
# Original text: Icyw
# Predicted: Icyw
#
# New best model saved with accuracy: 0.6060
# Epoch 70 complete, Average Loss: 0.4207
# Accuracy: 0.6060
# Sample 186
# Original text: Mnsu
# Predicted: Mnsu
#
# Epoch 71 complete, Average Loss: 0.3677
# Accuracy: 0.5600
# Sample 381
# Original text: mqur
# Predicted: nAr
#
# Epoch 72 complete, Average Loss: 0.3588
# Accuracy: 0.5480
# Sample 320
# Original text: mgGlkc
# Predicted: ngGlkc
#
# Epoch 73 complete, Average Loss: 0.3708
# Accuracy: 0.6060
# Sample 45
# Original text: ClFpb
# Predicted: ClfFpb
#
# Epoch 74 complete, Average Loss: 0.3995
# Accuracy: 0.4570
# Sample 293
# Original text: Ktez
# Predicted: Ktez
#
# Epoch 75 complete, Average Loss: 0.4188
# Accuracy: 0.5790
# Sample 969
# Original text: Jgqpkcj
# Predicted: Jgqpkcj
#
# Epoch 76 complete, Average Loss: 0.3588
# Accuracy: 0.5950
# Sample 970
# Original text: Xdewq
# Predicted: Xdewq
#
# Epoch 77 complete, Average Loss: 0.3390
# Accuracy: 0.5870
# Sample 160
# Original text: Sjeuxfz
# Predicted: Sjeuxfz
#
# Epoch 78 complete, Average Loss: 0.4186
# Accuracy: 0.5890
# Sample 502
# Original text: SOWH
# Predicted: SOWH
#
# New best model saved with accuracy: 0.6330
# Epoch 79 complete, Average Loss: 0.3655
# Accuracy: 0.6330
# Sample 113
# Original text: Rjtqms
# Predicted: RjtqmS
#
# Epoch 80 complete, Average Loss: 0.3199
# Accuracy: 0.6200
# Sample 44
# Original text: IBErzNf
# Predicted: IBErzNIr
#
# Epoch 81 complete, Average Loss: 0.3366
# Accuracy: 0.6310
# Sample 966
# Original text: Nfgubla
# Predicted: Nfgubla
#
# Epoch 82 complete, Average Loss: 0.3261
# Accuracy: 0.5370
# Sample 195
# Original text: uajvl
# Predicted: dojvl
#
# Epoch 83 complete, Average Loss: 0.3618
# Accuracy: 0.6070
# Sample 434
# Original text: Tblfc
# Predicted: Tblfc
#
# Epoch 84 complete, Average Loss: 0.3431
# Accuracy: 0.6290
# Sample 159
# Original text: Ggjdj
# Predicted: Ggjdj
#
# Epoch 85 complete, Average Loss: 0.3531
# Accuracy: 0.5480
# Sample 116
# Original text: Rhva
# Predicted: Rhva
#
# Epoch 86 complete, Average Loss: 0.3829
# Accuracy: 0.5820
# Sample 94
# Original text: lROz
# Predicted: IRDz
#
# New best model saved with accuracy: 0.6470
# Epoch 87 complete, Average Loss: 0.3437
# Accuracy: 0.6470
# Sample 367
# Original text: Bxhoy
# Predicted: Bxhoy
#
# New best model saved with accuracy: 0.6620
# Epoch 88 complete, Average Loss: 0.3124
# Accuracy: 0.6620
# Sample 901
# Original text: UfuqD
# Predicted: ufuqD
#
# Epoch 89 complete, Average Loss: 0.3278
# Accuracy: 0.6080
# Sample 28
# Original text: QoIffa
# Predicted: QoIffa
#
# Epoch 90 complete, Average Loss: 0.3752
# Accuracy: 0.6570
# Sample 871
# Original text: Hifkzgk
# Predicted: Hifkzgk
#
# Epoch 91 complete, Average Loss: 0.3325
# Accuracy: 0.5790
# Sample 626
# Original text: KvvoxA
# Predicted: KvvoXA
#
# Epoch 92 complete, Average Loss: 0.3336
# Accuracy: 0.6230
# Sample 878
# Original text: Njxd
# Predicted: Uxd
#
# Epoch 93 complete, Average Loss: 0.3800
# Accuracy: 0.5310
# Sample 716
# Original text: Lcmw
# Predicted: Lcmw
#
# Epoch 94 complete, Average Loss: 0.3308
# Accuracy: 0.6020
# Sample 631
# Original text: Fqyp
# Predicted: Fdyp
#
# Epoch 95 complete, Average Loss: 0.3529
# Accuracy: 0.6250
# Sample 736
# Original text: MggZput
# Predicted: MggZpuI
#
# Epoch 96 complete, Average Loss: 0.3395
# Accuracy: 0.5790
# Sample 194
# Original text: Jbac
# Predicted: Jbac
#
# Epoch 97 complete, Average Loss: 0.3265
# Accuracy: 0.6470
# Sample 62
# Original text: Anahb
# Predicted: Anahb
#
# Epoch 98 complete, Average Loss: 0.2938
# Accuracy: 0.6590
# Sample 304
# Original text: exaIUMP
# Predicted: axaIUMP
#
# Epoch 99 complete, Average Loss: 0.3093
# Accuracy: 0.5820
# Sample 446
# Original text: svtitFq
# Predicted: svtitFq
#
# Epoch 100 complete, Average Loss: 0.3184
# Accuracy: 0.6190
