# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset, random_split
from PIL import Image
import os
import random
import csv

class dataset(Dataset):
    def __init__(self, data_dir, transform):
        self.data_dir = data_dir
        self.image_files = []
        for file in os.listdir(self.data_dir):
            if file.endswith('.png'):
                img_path = os.path.join(self.data_dir, file)
                img = Image.open(img_path).convert('RGB')
                pixel = img.getpixel((0,0))
                is_red = pixel[0] > 128 and pixel[1] < 128 and pixel[2] < 128
                self.image_files.append((file, is_red))
        random.shuffle(self.image_files)
        
        self.transform = transform
        self.char_to_index = {char : (i+1) for i, char in enumerate("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ")}
        self.index_to_char = {self.char_to_index[char]:char for char in self.char_to_index}
        self.index_to_char[0] = '<blank>'
    
    def __len__(self):
        return len(self.image_files)
    
    def __getitem__(self, idx):
        img_name, is_red_background = self.image_files[idx]
        image_path = os.path.join(self.data_dir, img_name)
        image = Image.open(image_path).convert('L')
        image = self.transform(image)
        label = img_name[:-4]
        label = label[::-1] if is_red_background else label
        label_indices = [self.char_to_index[i] for i in label]
        return image, torch.tensor(label_indices), is_red_background

transform = transforms.Compose([
    transforms.Resize((32,128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

class CRNN(nn.Module):
    def __init__(self, num_chars):
        super().__init__()
        
        self.cnn = nn.Sequential(
            nn.Conv2d(1,64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),  # 64 --> 32
            nn.Dropout(0.1),
            
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d((2, 1)),  # 32 --> 16 only height
            nn.Dropout(0.1),
                
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d((2, 1)),  # 16 --> 8 only height
            nn.Dropout(0.1),   
        )
        
        self.lstm1 = nn.LSTM(512 * 2, 256, bidirectional=True, batch_first=True)
        self.linear1 = nn.Linear(512, 256)
        self.lstm2 = nn.LSTM(256, 256, bidirectional=True, batch_first=True)
        self.linear2 = nn.Linear(512, num_chars + 1)
        
    def forward(self,x):
        conv = self.cnn(x)  # [batch, 512, 2, 32]
        batch, channel, height, width = conv.size()
        conv = conv.permute(0, 3, 1, 2)  # [batch, width, channel, height]
        conv = conv.reshape(batch, width, channel * height)  # [batch, width, feature]
        
        lstm_out, _ = self.lstm1(conv)  # [batch, width, 512]
        lstm_out = self.linear1(lstm_out)  # [batch, width, 256]
        lstm_out, _ = self.lstm2(lstm_out)  # [batch, width, 512]
        output = self.linear2(lstm_out)  # [batch, width, num_chars + 1]
        return output

def decode_predictions(output, index_to_char):
    if len(output.shape) == 2:
        output = output.unsqueeze(0)
    
    output = nn.functional.log_softmax(output, dim=-1)
    predictions = torch.argmax(output, dim=-1) 
    
    batch_results = []
    for batch_pred in predictions:
        chars = []
        prev_char = None
        
        for p in batch_pred:
            char_idx = p.item()
            if char_idx != 0 and char_idx != prev_char:  
                if char_idx in index_to_char:
                    chars.append(index_to_char[char_idx])
            prev_char = char_idx
        
        batch_results.append(''.join(chars))
    
    return batch_results[0] if len(batch_results) == 1 else batch_results



def train_model(model, train_data, test_data, optimizer, loss_func, device, index_to_char, num_epochs=100):
    model.train()
    best_accuracy = 0
    
    for epoch in range(num_epochs):
        total_loss = 0
        for batch_idx, (images, labels, is_red_background) in enumerate(train_data):
            images = images.to(device)
            labels = labels.to(device)
            
            batch_size = images.size(0)
            outputs = model(images)  # [batch, width, num_chars + 1]
            
            input_lengths = torch.full(size=(batch_size,), fill_value=outputs.size(1), dtype=torch.long)
            target_lengths = torch.sum(labels != 0, dim=1)
            
            outputs = outputs.log_softmax(2) 
            outputs = outputs.permute(1, 0, 2)
            
            optimizer.zero_grad()
            loss = loss_func(outputs, labels, input_lengths, target_lengths)
            loss.backward()
            
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5)
            optimizer.step()
            
            total_loss += loss.item()
            
        model.eval()
        correct = 0
        total_samples = len(test_data.dataset)
        
        test_samples = list(test_data)
        random_sample = random.choice(test_samples)
        all_results = []
        
        with torch.no_grad():
            for i, (test_img, test_label, is_red_background) in enumerate(test_data):
                test_img = test_img.to(device)
                predicted_text = decode_predictions(model(test_img), index_to_char)
                true_text = ''.join([index_to_char[idx.item()] for idx in test_label[0] if idx.item() != 0])
                if is_red_background:
                    predicted_text = predicted_text[::-1]
                    true_text = true_text[::-1] 
                all_results.append({
                    'original': true_text,
                    'predicted': predicted_text,
                    'correct': predicted_text == true_text,
                })
                
                if predicted_text == true_text:
                    correct += 1
            
            test_img, test_label, is_red_background = random_sample
            test_img = test_img.to(device)
            predicted_text = decode_predictions(model(test_img), index_to_char)
            true_text = ''.join([index_to_char[idx.item()] for idx in test_label[0] if idx.item() != 0])
            
            print(f'Random Sample:')
            print('Red' if is_red_background[0] else 'Green')
            print(f'Original text: {true_text}')
            print(f'Predicted: {predicted_text}\n')
        
        accuracy = correct / total_samples
        
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'accuracy': accuracy,
            }, 'best_model.pth')
            
            with open('bonus4488.csv', 'w', newline='') as f:
                writer = csv.DictWriter(f, fieldnames=['original', 'predicted', 'correct'])
                writer.writeheader()
                writer.writerows(all_results)
            
            print(f'New best model saved with accuracy: {accuracy:.4f}')
            
        model.train()
        print(f'Epoch {epoch+1} complete, Average Loss: {total_loss/len(train_data):.4f}')
        print(f'Accuracy: {accuracy:.4f}')


def collate_fn(batch):
    batch.sort(key=lambda x: len(x[1]), reverse=True)
    images, labels, is_red_background = zip(*batch)
    images = torch.stack(images, 0)
    lengths = [len(label) for label in labels]
    max_length = max(lengths)
    padded_labels = torch.zeros(len(labels), max_length).long()
    for i, label in enumerate(labels):
        padded_labels[i, :len(label)] = label
        
    return images, padded_labels, is_red_background

data = dataset('/kaggle/input/bonus-5000/bonus_5000', transform)
num_chars = len(data.index_to_char) 
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = CRNN(num_chars).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_size = int(0.8 * len(data))
test_size = len(data) - train_size
train_dataset, test_dataset = random_split(data, [train_size, test_size])
train_data = DataLoader(train_dataset, batch_size=16, shuffle=True, collate_fn=collate_fn)
test_data = DataLoader(test_dataset, shuffle=True, collate_fn=collate_fn)
loss_func = nn.CTCLoss(blank=0, zero_infinity=True, reduction='mean')

train_model(model, train_data, test_data, optimizer, loss_func, device, data.index_to_char, num_epochs=100)
# Out:
# Random Sample:
# Green
# Original text: CWBkYG
# Predicted:
#
# Epoch 1 complete, Average Loss: 4.4889
# Accuracy: 0.0000
# Random Sample:
# Green
# Original text: CVMg
# Predicted:
#
# Epoch 2 complete, Average Loss: 4.2463
# Accuracy: 0.0000
# Random Sample:
# Red
# Original text: qtmDOEo
# Predicted:
#
# Epoch 3 complete, Average Loss: 4.1947
# Accuracy: 0.0000
# Random Sample:
# Red
# Original text: fDVtk
# Predicted: L
#
# Epoch 4 complete, Average Loss: 4.1228
# Accuracy: 0.0000
# Random Sample:
# Red
# Original text: ITQYy
# Predicted: BBBf
#
# Epoch 5 complete, Average Loss: 3.8182
# Accuracy: 0.0000
# Random Sample:
# Green
# Original text: uueh
# Predicted: dKeh
#
# Epoch 6 complete, Average Loss: 3.5316
# Accuracy: 0.0000
# Random Sample:
# Green
# Original text: DcKA
# Predicted: DcKh
#
# Epoch 7 complete, Average Loss: 3.0053
# Accuracy: 0.0000
# Random Sample:
# Green
# Original text: KlJOJz
# Predicted: EIJOIf
#
# New best model saved with accuracy: 0.0020
# Epoch 8 complete, Average Loss: 2.3866
# Accuracy: 0.0020
# Random Sample:
# Red
# Original text: ckjM
# Predicted: cMi
#
# New best model saved with accuracy: 0.0070
# Epoch 9 complete, Average Loss: 1.9031
# Accuracy: 0.0070
# Random Sample:
# Red
# Original text: HymXwQ
# Predicted: HvmXww
#
# New best model saved with accuracy: 0.0090
# Epoch 10 complete, Average Loss: 1.5425
# Accuracy: 0.0090
# Random Sample:
# Green
# Original text: OUwilvQ
# Predicted: Ctwdtw
#
# New best model saved with accuracy: 0.0230
# Epoch 11 complete, Average Loss: 1.3008
# Accuracy: 0.0230
# Random Sample:
# Green
# Original text: iZcTSO
# Predicted: iZcTSO
#
# New best model saved with accuracy: 0.0420
# Epoch 12 complete, Average Loss: 1.1081
# Accuracy: 0.0420
# Random Sample:
# Green
# Original text: pfzB
# Predicted: pfzH
#
# New best model saved with accuracy: 0.0560
# Epoch 13 complete, Average Loss: 0.9700
# Accuracy: 0.0560
# Random Sample:
# Green
# Original text: qojchq
# Predicted: qojchc
#
# New best model saved with accuracy: 0.1160
# Epoch 14 complete, Average Loss: 0.8705
# Accuracy: 0.1160
# Random Sample:
# Red
# Original text: OlWOol
# Predicted: OlMOoI
#
# Epoch 15 complete, Average Loss: 0.7788
# Accuracy: 0.0970
# Random Sample:
# Green
# Original text: YsFdCu
# Predicted: YsFdCA
#
# New best model saved with accuracy: 0.2460
# Epoch 16 complete, Average Loss: 0.6919
# Accuracy: 0.2460
# Random Sample:
# Green
# Original text: hYUi
# Predicted: hYt
#
# New best model saved with accuracy: 0.2680
# Epoch 17 complete, Average Loss: 0.6085
# Accuracy: 0.2680
# Random Sample:
# Red
# Original text: psUk
# Predicted: psUR
#
# New best model saved with accuracy: 0.3250
# Epoch 18 complete, Average Loss: 0.5424
# Accuracy: 0.3250
# Random Sample:
# Red
# Original text: nHSsZGe
# Predicted: nHSsZGe
#
# New best model saved with accuracy: 0.3680
# Epoch 19 complete, Average Loss: 0.4788
# Accuracy: 0.3680
# Random Sample:
# Green
# Original text: DiupKCi
# Predicted: DlupKCt
#
# New best model saved with accuracy: 0.4560
# Epoch 20 complete, Average Loss: 0.4255
# Accuracy: 0.4560
# Random Sample:
# Red
# Original text: UFnLN
# Predicted: UPutw
#
# New best model saved with accuracy: 0.4950
# Epoch 21 complete, Average Loss: 0.3700
# Accuracy: 0.4950
# Random Sample:
# Red
# Original text: RtZUBy
# Predicted: RtZUBy
#
# New best model saved with accuracy: 0.5050
# Epoch 22 complete, Average Loss: 0.3013
# Accuracy: 0.5050
# Random Sample:
# Green
# Original text: lzeiDQe
# Predicted: lzeiDQs
#
# New best model saved with accuracy: 0.5590
# Epoch 23 complete, Average Loss: 0.2702
# Accuracy: 0.5590
# Random Sample:
# Red
# Original text: ZOfA
# Predicted: zOA
#
# New best model saved with accuracy: 0.5740
# Epoch 24 complete, Average Loss: 0.2257
# Accuracy: 0.5740
# Random Sample:
# Green
# Original text: bfgXC
# Predicted: bfgXC
#
# New best model saved with accuracy: 0.6060
# Epoch 25 complete, Average Loss: 0.2022
# Accuracy: 0.6060
# Random Sample:
# Red
# Original text: VKyV
# Predicted: VKyV
#
# New best model saved with accuracy: 0.6370
# Epoch 26 complete, Average Loss: 0.1875
# Accuracy: 0.6370
# Random Sample:
# Green
# Original text: CoESQ
# Predicted: CoESQ
#
# New best model saved with accuracy: 0.6500
# Epoch 27 complete, Average Loss: 0.1612
# Accuracy: 0.6500
# Random Sample:
# Red
# Original text: HlTG
# Predicted: HTC
#
# New best model saved with accuracy: 0.6860
# Epoch 28 complete, Average Loss: 0.1528
# Accuracy: 0.6860
# Random Sample:
# Green
# Original text: ZjPHIk
# Predicted: ZjPHlk
#
# Epoch 29 complete, Average Loss: 0.1474
# Accuracy: 0.6480
# Random Sample:
# Green
# Original text: CVMg
# Predicted: CVMs
#
# New best model saved with accuracy: 0.7180
# Epoch 30 complete, Average Loss: 0.1208
# Accuracy: 0.7180
# Random Sample:
# Red
# Original text: lWsab
# Predicted: lWsab
#
# Epoch 31 complete, Average Loss: 0.1113
# Accuracy: 0.6890
# Random Sample:
# Green
# Original text: oJFNee
# Predicted: oJFNec
#
# Epoch 32 complete, Average Loss: 0.1027
# Accuracy: 0.6950
# Random Sample:
# Green
# Original text: vFys
# Predicted: vFys
#
# Epoch 33 complete, Average Loss: 0.1093
# Accuracy: 0.6940
# Random Sample:
# Green
# Original text: lMpq
# Predicted: lMpq
#
# Epoch 34 complete, Average Loss: 0.0934
# Accuracy: 0.7010
# Random Sample:
# Red
# Original text: XYnSDb
# Predicted: XYnSDb
#
# New best model saved with accuracy: 0.7290
# Epoch 35 complete, Average Loss: 0.0811
# Accuracy: 0.7290
# Random Sample:
# Red
# Original text: JRrcQi
# Predicted: JNrcQl
#
# Epoch 36 complete, Average Loss: 0.0856
# Accuracy: 0.7110
# Random Sample:
# Green
# Original text: dBAmQc
# Predicted: dBAmQc
#
# Epoch 37 complete, Average Loss: 0.1087
# Accuracy: 0.7130
# Random Sample:
# Green
# Original text: XqglhVd
# Predicted: XqgIhVd
#
# New best model saved with accuracy: 0.7410
# Epoch 38 complete, Average Loss: 0.0863
# Accuracy: 0.7410
# Random Sample:
# Green
# Original text: qrdOjGo
# Predicted: qrdOjGo
#
# Epoch 39 complete, Average Loss: 0.0799
# Accuracy: 0.6300
# Random Sample:
# Green
# Original text: bxJt
# Predicted: bxJt
#
# Epoch 40 complete, Average Loss: 0.0940
# Accuracy: 0.6480
# Random Sample:
# Green
# Original text: eWDbkRo
# Predicted: eWDbkRo
#
# Epoch 41 complete, Average Loss: 0.0751
# Accuracy: 0.6810
# Random Sample:
# Green
# Original text: CafhMu
# Predicted: CafhMu
#
# Epoch 42 complete, Average Loss: 0.0761
# Accuracy: 0.7320
# Random Sample:
# Green
# Original text: zCSilxP
# Predicted: zCSilxP
#
# Epoch 43 complete, Average Loss: 0.0752
# Accuracy: 0.7190
# Random Sample:
# Red
# Original text: nvXCYU
# Predicted: nvxCTU
#
# Epoch 44 complete, Average Loss: 0.0656
# Accuracy: 0.7320
# Random Sample:
# Red
# Original text: LMmcY
# Predicted: LMmcy
#
# Epoch 45 complete, Average Loss: 0.0661
# Accuracy: 0.6880
# Random Sample:
# Green
# Original text: pfzB
# Predicted: pfzB
#
# Epoch 46 complete, Average Loss: 0.0689
# Accuracy: 0.6860
# Random Sample:
# Red
# Original text: bGdRoU
# Predicted: bGdRoU
#
# New best model saved with accuracy: 0.7490
# Epoch 47 complete, Average Loss: 0.0581
# Accuracy: 0.7490
# Random Sample:
# Green
# Original text: tgCP
# Predicted: tgCP
#
# Epoch 48 complete, Average Loss: 0.0475
# Accuracy: 0.6970
# Random Sample:
# Red
# Original text: gAzkG
# Predicted: gAzkG
#
# Epoch 49 complete, Average Loss: 0.0561
# Accuracy: 0.7450
# Random Sample:
# Green
# Original text: cILWHc
# Predicted: cTLWHc
#
# Epoch 50 complete, Average Loss: 0.0510
# Accuracy: 0.7120
# Random Sample:
# Green
# Original text: NFIothl
# Predicted: NFIothl
#
# Epoch 51 complete, Average Loss: 0.0453
# Accuracy: 0.7260
# Random Sample:
# Red
# Original text: cBAJJD
# Predicted: cBAJJD
#
# Epoch 52 complete, Average Loss: 0.0629
# Accuracy: 0.7260
# Random Sample:
# Green
# Original text: TfskYq
# Predicted: TfskYq
#
# Epoch 53 complete, Average Loss: 0.0561
# Accuracy: 0.7440
# Random Sample:
# Red
# Original text: TvQbTin
# Predicted: TvQbTin
#
# Epoch 54 complete, Average Loss: 0.0489
# Accuracy: 0.6840
# Random Sample:
# Red
# Original text: ezSL
# Predicted: ezSL
#
# Epoch 55 complete, Average Loss: 0.0488
# Accuracy: 0.7190
# Random Sample:
# Red
# Original text: evDjl
# Predicted: evDji
#
# Epoch 56 complete, Average Loss: 0.0467
# Accuracy: 0.7440
# Random Sample:
# Red
# Original text: wmenkh
# Predicted: wWmcnkh
#
# Epoch 57 complete, Average Loss: 0.0546
# Accuracy: 0.6940
# Random Sample:
# Green
# Original text: CEiAcc
# Predicted: CELxce
#
# Epoch 58 complete, Average Loss: 0.0543
# Accuracy: 0.7180
# Random Sample:
# Green
# Original text: zAZwh
# Predicted: zAZwh
#
# New best model saved with accuracy: 0.7780
# Epoch 59 complete, Average Loss: 0.0517
# Accuracy: 0.7780
# Random Sample:
# Red
# Original text: tBUQ
# Predicted: tBUQ
#
# Epoch 60 complete, Average Loss: 0.0532
# Accuracy: 0.7500
# Random Sample:
# Red
# Original text: bxlqN
# Predicted: bxIqN
#
# Epoch 61 complete, Average Loss: 0.0588
# Accuracy: 0.7050
# Random Sample:
# Red
# Original text: UqEmN
# Predicted: UqEmN
#
# Epoch 62 complete, Average Loss: 0.0386
# Accuracy: 0.7500
# Random Sample:
# Green
# Original text: sKLqhe
# Predicted: sKLqhe
#
# Epoch 63 complete, Average Loss: 0.0351
# Accuracy: 0.7530
# Random Sample:
# Red
# Original text: qtmDOEo
# Predicted: qtmDOEo
#
# Epoch 64 complete, Average Loss: 0.0341
# Accuracy: 0.7770
# Random Sample:
# Green
# Original text: zvAFImW
# Predicted: zvAFImW
#
# Epoch 65 complete, Average Loss: 0.0236
# Accuracy: 0.7550
# Random Sample:
# Green
# Original text: VwGAvc
# Predicted: VwGAvc
#
# Epoch 66 complete, Average Loss: 0.0537
# Accuracy: 0.7300
# Random Sample:
# Red
# Original text: nzbSx
# Predicted: nzbSx
#
# Epoch 67 complete, Average Loss: 0.0539
# Accuracy: 0.7030
# Random Sample:
# Red
# Original text: bzVb
# Predicted: bzVb
#
# Epoch 68 complete, Average Loss: 0.0456
# Accuracy: 0.7390
# Random Sample:
# Green
# Original text: UWImiZ
# Predicted: UWlmiZ
#
# Epoch 69 complete, Average Loss: 0.0476
# Accuracy: 0.7450
# Random Sample:
# Red
# Original text: LwZIHME
# Predicted: LwZlMME
#
# Epoch 70 complete, Average Loss: 0.0415
# Accuracy: 0.7670
# Random Sample:
# Red
# Original text: Pvle
# Predicted: Pvle
#
# Epoch 71 complete, Average Loss: 0.0274
# Accuracy: 0.7780
# Random Sample:
# Red
# Original text: eXAAkQY
# Predicted: eXAAkQY
#
# Epoch 72 complete, Average Loss: 0.0321
# Accuracy: 0.7450
# Random Sample:
# Red
# Original text: jQyOw
# Predicted: jQyOw
#
# Epoch 73 complete, Average Loss: 0.0385
# Accuracy: 0.7570
# Random Sample:
# Red
# Original text: cTtXT
# Predicted: cFtXT
#
# Epoch 74 complete, Average Loss: 0.0411
# Accuracy: 0.7570
# Random Sample:
# Green
# Original text: DXqX
# Predicted: DXqX
#
# Epoch 75 complete, Average Loss: 0.0363
# Accuracy: 0.7430
# Random Sample:
# Red
# Original text: aXeCo
# Predicted: aXeCo
#
# Epoch 76 complete, Average Loss: 0.0342
# Accuracy: 0.7360
# Random Sample:
# Red
# Original text: qXrm
# Predicted: qXrm
#
# Epoch 77 complete, Average Loss: 0.0357
# Accuracy: 0.7450
# Random Sample:
# Red
# Original text: NWUZ
# Predicted: NWUZ
#
# Epoch 78 complete, Average Loss: 0.0351
# Accuracy: 0.7420
# Random Sample:
# Red
# Original text: nCWqyn
# Predicted: mCWqyn
#
# Epoch 79 complete, Average Loss: 0.0410
# Accuracy: 0.7490
# Random Sample:
# Green
# Original text: jikgn
# Predicted: jlkgn
#
# Epoch 80 complete, Average Loss: 0.0447
# Accuracy: 0.7680
# Random Sample:
# Green
# Original text: eTtZYx
# Predicted: eTUZYx
#
# Epoch 81 complete, Average Loss: 0.0368
# Accuracy: 0.7450
# Random Sample:
# Red
# Original text: QDfGs
# Predicted: QDfGs
#
# Epoch 82 complete, Average Loss: 0.0309
# Accuracy: 0.7100
# Random Sample:
# Green
# Original text: Slziuf
# Predicted: Slziuf
#
# Epoch 83 complete, Average Loss: 0.0385
# Accuracy: 0.7450
# Random Sample:
# Green
# Original text: WvpbV
# Predicted: WvpbV
#
# New best model saved with accuracy: 0.7980
# Epoch 84 complete, Average Loss: 0.0263
# Accuracy: 0.7980
# Random Sample:
# Green
# Original text: eQkM
# Predicted: eQkM
#
# Epoch 85 complete, Average Loss: 0.0402
# Accuracy: 0.7330
# Random Sample:
# Green
# Original text: FcVHS
# Predicted: FcVHS
#
# Epoch 86 complete, Average Loss: 0.0253
# Accuracy: 0.7780
# Random Sample:
# Red
# Original text: UvBS
# Predicted: UvBS
#
# Epoch 87 complete, Average Loss: 0.0175
# Accuracy: 0.7760
# Random Sample:
# Green
# Original text: vKmEi
# Predicted: vKmEi
#
# Epoch 88 complete, Average Loss: 0.0413
# Accuracy: 0.7610
# Random Sample:
# Red
# Original text: BNsB
# Predicted: BNsB
#
# Epoch 89 complete, Average Loss: 0.0313
# Accuracy: 0.7290
# Random Sample:
# Green
# Original text: AaVZM
# Predicted: AaVZM
#
# Epoch 90 complete, Average Loss: 0.0299
# Accuracy: 0.7630
# Random Sample:
# Red
# Original text: FoIkvL
# Predicted: FoIkvL
#
# Epoch 91 complete, Average Loss: 0.0316
# Accuracy: 0.7060
# Random Sample:
# Green
# Original text: isnKM
# Predicted: lsnKM
#
# Epoch 92 complete, Average Loss: 0.0293
# Accuracy: 0.7440
# Random Sample:
# Green
# Original text: DxUs
# Predicted: DxUz
#
# Epoch 93 complete, Average Loss: 0.0248
# Accuracy: 0.7760
# Random Sample:
# Green
# Original text: UWImiZ
# Predicted: UWlmiZ
#
# Epoch 94 complete, Average Loss: 0.0232
# Accuracy: 0.7780
# Random Sample:
# Red
# Original text: JTXZjtD
# Predicted: JTXZjtD
#
# Epoch 95 complete, Average Loss: 0.0222
# Accuracy: 0.7560
# Random Sample:
# Red
# Original text: bXkmlP
# Predicted: bXkmlP
#
# Epoch 96 complete, Average Loss: 0.0411
# Accuracy: 0.7510
# Random Sample:
# Red
# Original text: QReBXn
# Predicted: QReBXn
#
# Epoch 97 complete, Average Loss: 0.0403
# Accuracy: 0.7770
# Random Sample:
# Red
# Original text: vZaMhpz
# Predicted: VZaMhpz
#
# Epoch 98 complete, Average Loss: 0.0207
# Accuracy: 0.7700
# Random Sample:
# Green
# Original text: pjqmeHu
# Predicted: pjqmeHu
#
# Epoch 99 complete, Average Loss: 0.0309
# Accuracy: 0.7690
# Random Sample:
# Green
# Original text: LUcS
# Predicted: LUcS
#
# Epoch 100 complete, Average Loss: 0.0252
# Accuracy: 0.7310
